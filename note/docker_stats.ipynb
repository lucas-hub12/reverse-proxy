# %%
import pandas as pd

# %%
df =pd.read_csv("docker_stats.csv")
df["Timestamp"] = pd.to_datetime(df["Timestamp"], unit='s')

# %%
df
# Out:
#              Timestamp     Container                        Name  \
# 0  2025-02-27 02:13:56  6acec2d9b5e1       reverse-proxy-agent-1
# 1  2025-02-27 02:13:56  b3beabe2910e  reverse-proxy-controller-1
# 2  2025-02-27 02:14:08  6acec2d9b5e1       reverse-proxy-agent-1
# 3  2025-02-27 02:14:08  b3beabe2910e  reverse-proxy-controller-1
# 4  2025-02-27 02:14:22  6acec2d9b5e1       reverse-proxy-agent-1
# 5  2025-02-27 02:14:22  b3beabe2910e  reverse-proxy-controller-1
# 6  2025-02-27 02:14:34  6acec2d9b5e1       reverse-proxy-agent-1
# 7  2025-02-27 02:14:34  b3beabe2910e  reverse-proxy-controller-1
# 8  2025-02-27 02:14:47  6acec2d9b5e1       reverse-proxy-agent-1
# 9  2025-02-27 02:14:47  b3beabe2910e  reverse-proxy-controller-1
# 10 2025-02-27 02:15:01  6acec2d9b5e1       reverse-proxy-agent-1
# 11 2025-02-27 02:15:01  b3beabe2910e  reverse-proxy-controller-1
# 12 2025-02-27 02:15:13  6acec2d9b5e1       reverse-proxy-agent-1
# ...
